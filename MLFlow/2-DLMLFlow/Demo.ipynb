# %% [markdown]
# ### Quickstart: Compare runs, choose a model, and deploy it to a REST API
#
# In this quickstart, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import tensorflow as tf
import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "winequality-white.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8])

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model
def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model = tf.keras.Sequential(
    [
        tf.keras.Input([train_x.shape[1]]),
        tf.keras.layers.Normalization(mean=mean, variance=var),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(1)
    ]
)


    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
## thats how hyperopt wants the objective function
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("wine-quality")

with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)


    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2025/01/21 20:21:48 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 36.8559 - root_mean_squared_error: 6.0709
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7979 - root_mean_squared_error: 4.3718 - val_loss: 2.5615 - val_root_mean_squared_error: 1.6005
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2512 - root_mean_squared_error: 1.5004
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 2.1470 - root_mean_squared_error: 1.4651 - val_loss: 1.8735 - val_root_mean_squared_error: 1.3688
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5781 - root_mean_squared_error: 1.6056
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 1.7712 - root_mean_squared_error: 1.3290 - val_loss: 1.5954 - val_root_mean_squared_error: 1.2631
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2750 - root_mean_squared_error: 1.1292
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6109 - root_mean_squared_error: 1.2680
#
# 🏃 View run brawny-dove-629 at: http://127.0.0.1:5000/#/experiments/568585262662934258/runs/3b670ec32a4f4d8abb7dd4b397a17364
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/568585262662934258
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 28.2189 - root_mean_squared_error: 5.3121
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.6510 - root_mean_squared_error: 3.8896 - val_loss: 2.7687 - val_root_mean_squared_error: 1.6639
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8224 - root_mean_squared_error: 1.6800
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 2.4040 - root_mean_squared_error: 1.5494 - val_loss: 2.0208 - val_root_mean_squared_error: 1.4215
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7261 - root_mean_squared_error: 1.3138
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 1.7793 - root_mean_squared_error: 1.3337 - val_loss: 1.6945 - val_root_mean_squared_error: 1.3017
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3558 - root_mean_squared_error: 1.1644
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7038 - root_mean_squared_error: 1.3041
#
# 🏃 View run blushing-cat-121 at: http://127.0.0.1:5000/#/experiments/568585262662934258/runs/61180a0c136e4511b2673554578db2ce
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/568585262662934258
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 8s 180ms/step - loss: 42.8579 - root_mean_squared_error: 6.5466
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.0286 - root_mean_squared_error: 2.9555 - val_loss: 0.9988 - val_root_mean_squared_error: 0.9994
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8803 - root_mean_squared_error: 0.9383
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.8560 - root_mean_squared_error: 0.9251 - val_loss: 0.7434 - val_root_mean_squared_error: 0.8622
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7014 - root_mean_squared_error: 0.8375
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.6603 - root_mean_squared_error: 0.8124 - val_loss: 0.6447 - val_root_mean_squared_error: 0.8029
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6262 - root_mean_squared_error: 0.7913
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6398 - root_mean_squared_error: 0.7996
#
# 🏃 View run able-snail-761 at: http://127.0.0.1:5000/#/experiments/568585262662934258/runs/ed79086837bb49d08e38f24c67765730
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/568585262662934258
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 35.2520 - root_mean_squared_error: 5.9373
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.1190 - root_mean_squared_error: 5.4788 - val_loss: 15.0925 - val_root_mean_squared_error: 3.8849
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.2169 - root_mean_squared_error: 3.9009
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 11.9391 - root_mean_squared_error: 3.4475 - val_loss: 5.8193 - val_root_mean_squared_error: 2.4123
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5034 - root_mean_squared_error: 2.3459
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 4.6268 - root_mean_squared_error: 2.1484 - val_loss: 2.8929 - val_root_mean_squared_error: 1.7009
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5191 - root_mean_squared_error: 1.5872
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7633 - root_mean_squared_error: 1.6618
#
# 🏃 View run bittersweet-lark-507 at: http://127.0.0.1:5000/#/experiments/568585262662934258/runs/64238394c57c4743ad1063a68af1255a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/568585262662934258
#
# 100%|██████████| 4/4 [00:18<00:00,  4.74s/trial, best loss: 0.8029339909553528]
# Best parameters: {'lr': 0.012891153446834929, 'momentum': 0.6424473556736365}
# Best eval rmse: 0.8029339909553528
# 🏃 View run gaudy-fox-81 at: http://127.0.0.1:5000/#/experiments/568585262662934258/runs/ded3230bab064afba92d23377db35956
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/568585262662934258

# %% [markdown]
# ## Loading the model

# %%
from mlflow.models import validate_serving_input

model_uri = 'runs:/ded3230bab064afba92d23377db35956/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# Downloading artifacts:   0%|          | 0/7 [01:03<?, ?it/s]
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[32], line 14
#      11 serving_payload = convert_input_example_to_serving_input(test_x)
#      13 # Validate the serving payload works on the model
# ---> 14 validate_serving_input(model_uri, serving_payload)
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/models/utils.py:1874, in validate_serving_input(model_uri, serving_input)
#    1871 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    1873 try:
# -> 1874     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    1875     parsed_input = _parse_json_data(
#    1876         serving_input,
#    1877         pyfunc_model.metadata,
#    1878         pyfunc_model.metadata.get_input_schema(),
#    1879     )
#    1880     return pyfunc_model.predict(parsed_input.data, params=parsed_input.params)
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/tracing/provider.py:309, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     307 disable()
#     308 try:
# --> 309     is_func_called, result = True, f(*args, **kwargs)
#     310 finally:
#     311     enable()
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/pyfunc/__init__.py:1033, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1029         entity_list.append(Entity(job=job_entity))
#    1031     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1033 local_path = _download_artifact_from_uri(
#    1034     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1035 )
#    1037 if not suppress_warnings:
#    1038     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:116, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
# --> 116 return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/store/artifact/runs_artifact_repo.py:131, in RunsArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     114 def download_artifacts(self, artifact_path, dst_path=None):
#     115     """
#     116     Download an artifact file or directory to a local directory if applicable, and return a
#     117     local path for it.
#    (...)
#     129         Absolute path of the local filesystem location containing the desired artifacts.
#     130     """
# --> 131     return self.repo.download_artifacts(artifact_path, dst_path)
#
# File ~/Desktop/MLOPS/.venv/lib/python3.12/site-packages/mlflow/store/artifact/artifact_repo.py:302, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     296         template = "##### File {path} #####\n{error}"
#     298     failures = "\n".join(
#     299         template.format(path=path, error=error, traceback=tracebacks[path])
#     300         for path, error in failed_downloads.items()
#     301     )
# --> 302     raise MlflowException(
#     303         message=(
#     304             "The following failures occurred while downloading one or more"
#     305             f" artifacts from {self.artifact_uri}:\n{_truncate_error(failures)}"
#     306         )
#     307     )
#     309 return os.path.join(dst_path, artifact_path)
#
# MlflowException: The following failures occurred while downloading one or more artifacts from http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts:
# ##### File model/data/model.keras #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/model.keras failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/model.keras (Caused by ResponseError('too many 500 error responses'))
# ##### File model/data/save_format.txt #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/save_format.txt failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/save_format.txt (Caused by ResponseError('too many 500 error responses'))
# ##### File model/python_env.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/python_env.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/python_env.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File model/data/keras_module.txt #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/keras_module.txt failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/data/keras_module.txt (Caused by ResponseError('too many 500 error responses'))
# ##### File model/requirements.txt #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/requirements.txt failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/requirements.txt (Caused by ResponseError('too many 500 error responses'))
# ##### File model/conda.yaml #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/conda.yaml failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/conda.yaml (Caused by ResponseError('too many 500 error responses'))
# ##### File model/MLmodel #####
# API request to http://127.0.0.1:5000/api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/MLmodel failed with exception HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /api/2.0/mlflow-artifacts/artifacts/568585262662934258/ded3230bab064afba92d23377db35956/artifacts/model/MLmodel (Caused by ResponseError('too many 500 error responses'))
